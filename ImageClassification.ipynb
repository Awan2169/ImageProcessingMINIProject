# %%
import pandas as pd
import numpy as np

df= pd.read_csv("Image_features_Dataset.csv")
df.head()

#preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
df['label'] = df['label'].map({"Real":0 , "AI":1}) 
features = [
    'histogram_skew',
    'high_freq_ratio',
    'mean_r',
    'mean_g',
    'mean_b',
    'std_r',
    'std_g',
    'std_b',
    'entropy',
    'homogeneity',
    'contrast',
    'correlation',
    'dissimilarity',
    'noise_std',
    'edge_density',
    'edge_strength',
    'fft_energy',
    'laplacian_variance',
    'sharpness'
]
X= df[features]
Y = df['label']

scaler = StandardScaler()
X=scaler.fit_transform(X)

x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=1)

from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    max_depth=8,
    min_samples_split=6,
    min_samples_leaf=3,
    random_state=42,
    n_estimators=300)
model.fit(x_train, y_train)

accuracy = model.score(x_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7538461538461538

# %%
correlation = df.corr()['label'].sort_values(ascending=True)

print(correlation)
# Out:
# mean_g               -0.280584
# mean_b               -0.223476
# mean_r               -0.211852
# high_freq_ratio      -0.192149
# dissimilarity        -0.133377
# laplacian_variance   -0.126349
# sharpness            -0.126349
# fft_energy           -0.113018
# contrast             -0.110152
# edge_strength        -0.097201
# std_r                -0.090688
# edge_density         -0.090265
# energy               -0.081221
# color_corr_gb        -0.035143
# lbp                  -0.007963
# color_corr_rb         0.000588
# color_corr_rg         0.021804
# noise_std             0.038471
# std_g                 0.061005
# homogeneity           0.084039
# entropy               0.112793
# std_b                 0.121136
# correlation           0.129693
# histogram_skew        0.252345
# label                 1.000000
# Name: label, dtype: float64
