# %%
import numpy as np
import pandas as pd

# Load data
df = pd.read_csv("Image_features_Dataset.csv")

# Encode labels
mapp = {"AI": 0, "Real": 1}
df["label"] = df["label"].map(mapp)

# Split features and target
X = df.drop(columns=["label"])
y = df["label"].values

# Train-test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Scaling (VERY important for ANN)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Build improved ANN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.4),

    Dense(64, activation='relu'),
    Dropout(0.3),

    Dense(32, activation='relu'),

    Dense(1, activation='sigmoid')
])

from tensorflow.keras.optimizers import Adam
optimizer = Adam(learning_rate=0.0005)

model.compile(
    optimizer=optimizer,
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=10,
    batch_size=16,
    verbose=1
)

# Predictions
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()

# Evaluation
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Epoch 1/10
# c:\Users\kayus\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5798 - loss: 0.6892 - val_accuracy: 0.6496 - val_loss: 0.6632
# Epoch 2/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6459 - loss: 0.6611 - val_accuracy: 0.6496 - val_loss: 0.6495
# Epoch 3/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6312 - loss: 0.6528 - val_accuracy: 0.6496 - val_loss: 0.6375
# Epoch 4/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6330 - loss: 0.6492 - val_accuracy: 0.6642 - val_loss: 0.6269
# Epoch 5/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6495 - loss: 0.6413 - val_accuracy: 0.6642 - val_loss: 0.6256
# Epoch 6/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6606 - loss: 0.6272 - val_accuracy: 0.6642 - val_loss: 0.6216
# Epoch 7/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6826 - loss: 0.5950 - val_accuracy: 0.6423 - val_loss: 0.6187
# Epoch 8/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6771 - loss: 0.6132 - val_accuracy: 0.6204 - val_loss: 0.6198
# Epoch 9/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6899 - loss: 0.5970 - val_accuracy: 0.5985 - val_loss: 0.6243
# Epoch 10/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7193 - loss: 0.5752 - val_accuracy: 0.6423 - val_loss: 0.6205
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Accuracy: 0.7133105802047781
#
# Confusion Matrix:
#  [[125  37]
#  [ 47  84]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.77      0.75       162
#            1       0.69      0.64      0.67       131
#
#     accuracy                           0.71       293
#    macro avg       0.71      0.71      0.71       293
# weighted avg       0.71      0.71      0.71       293
